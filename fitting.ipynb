# %%
import pandas as pd

# %%
data = pd.read_excel("strategy_results_train.xlsx")

# %%
data.head()
# Out:
#                    id  label       date       open       high        low  \
# 0  SHSE.600085_201501      0 2014-12-30  20.900000  22.090000  20.799999
# 1  SHSE.600085_201502      1 2015-01-30  22.990000  23.190001  22.510000
# 2  SHSE.600085_201503      1 2015-02-27  22.520000  22.670000  22.400000
# 3  SHSE.600085_201504      1 2015-03-30  26.219999  26.440001  25.820000
# 4  SHSE.600085_201505      1 2015-04-29  32.580002  33.639999  32.279999
#
#        close    volume        RSI      MACD  ...   BBANDS_3       KD_1  \
# 0  22.049999  25457468  67.422912  0.300741  ...  20.492360  60.969460
# 1  22.580000   7880595  33.069972  0.306613  ...  22.174364   4.780284
# 2  22.540001   9263796  57.292366 -0.112559  ...  22.150410  74.944776
# 3  26.230000  16125626  73.065077  0.969363  ...  25.758658  72.816074
# 4  33.180000  13959795  60.800069  1.955272  ...  32.047581  45.784935
#
#         KD_2        ADX      WILLR      BETA        TSF      ROCP        WMA  \
# ...

# %%
data2 = pd.concat( [data.iloc[:, 1], data.iloc[:, 8:11], data.iloc[:, 16], data.iloc[:, 19:21], data.iloc[:, -1]], axis=1)

# %%
data2.head()
# Out:
#    label        RSI      MACD       MOM        ADX        TSF      ROCP  \
# 0      0  67.422912  0.300741  0.980000  28.423399  21.027362  0.010541
# 1      1  33.069972  0.306613 -0.860001  22.025821  23.041978 -0.075727
# 2      1  57.292366 -0.112559  0.610001  27.777632  22.314286 -0.003096
# 3      1  73.065077  0.969363  1.770000  31.111115  27.123846  0.108154
# 4      1  60.800069  1.955272 -0.349998  48.542510  33.413407  0.047348
#
#          OBV
# 0  214347329
# 1  209047450
# 2  205917884
# 3  392580996
# 4  682246566

# %%
data2.isnull().any()
# Out:
# label    False
# RSI       True
# MACD      True
# MOM       True
# ADX       True
# TSF       True
# ROCP      True
# OBV      False
# dtype: bool

# %%
data2 = data2.dropna(axis = 0)
data2.isnull().any()
# Out:
# label    False
# RSI      False
# MACD     False
# MOM      False
# ADX      False
# TSF      False
# ROCP     False
# OBV      False
# dtype: bool

# %%
y = data2["label"]
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 31942    1
# 31943    0
# 31944    0
# 31945    0
# 31946    0
# Name: label, Length: 31779, dtype: int64

# %%
X = data2.iloc[:, 1:]

# %%
X
# Out:
#              RSI      MACD       MOM        ADX        TSF      ROCP  \
# 0      67.422912  0.300741  0.980000  28.423399  21.027362  0.010541
# 1      33.069972  0.306613 -0.860001  22.025821  23.041978 -0.075727
# 2      57.292366 -0.112559  0.610001  27.777632  22.314286 -0.003096
# 3      73.065077  0.969363  1.770000  31.111115  27.123846  0.108154
# 4      60.800069  1.955272 -0.349998  48.542510  33.413407  0.047348
# ...          ...       ...       ...        ...        ...       ...
# 31942  35.793793  0.941104 -0.400002  24.505867  57.768901 -0.124981
# 31943  40.306764 -0.196820 -3.599998  12.259172  56.088461 -0.002732
# 31944  79.180987  0.209077  5.100002  15.088968  55.814724  0.119883
# 31945  37.476424 -2.132327 -0.570000  21.943246  42.647912 -0.150184
# 31946  25.939419 -0.497961 -2.539997  13.751178  47.871979 -0.101991
#
#              OBV
# 0      214347329
# 1      209047450
# 2      205917884
# 3      392580996
# 4      682246566
# ...          ...
# ...

# %%
X = X.dropna(axis = 0)

# %%
X.isnull().any()
# Out:
# RSI     False
# MACD    False
# MOM     False
# ADX     False
# TSF     False
# ROCP    False
# OBV     False
# dtype: bool

# %%
X.shape
# Out:
# (31779, 7)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
testdata = pd.read_excel("sampleSubmission.xlsx")

# %%
testdata = testdata.fillna(0)
testdata.isnull().any()
# Out:
# id          False
# label       False
# RSI         False
# MACD        False
# MOM         False
# BBANDS_1    False
# ...         False
# BBANDS_3    False
# KD_1        False
# KD_2        False
# ADX         False
# WILLR       False
# BETA        False
# TSF         False
# ROCP        False
# WMA         False
# OBV         False
# dtype: bool

# %%
testdata.iloc[:, 2:]
# Out:
#              RSI      MACD       MOM   BBANDS_1        ...   BBANDS_3  \
# 0      43.920689 -0.624064  0.670000  27.582074  27.258000  26.933926
# 1      36.866876 -0.324989 -0.440001  26.813146  26.624000  26.434854
# 2      61.148764  0.504432  0.840000  30.116441  28.890000  27.663558
# 3      51.549343  0.194734 -0.139999  30.050521  29.532000  29.013479
# 4      35.287002  0.314845 -1.560001  32.667679  31.514000  30.360321
# ...          ...       ...       ...        ...        ...        ...
# 11358  35.912823  2.113382 -3.099998  88.993324  86.210001  83.426677
# 11359  25.796770 -2.078858 -3.040001  79.284844  77.136000  74.987156
# 11360  53.018605 -2.372954  0.650002  72.778118  70.966000  69.153882
# 11361  65.575880  2.246607  5.570000  88.903545  82.976001  77.048457
# 11362  41.500225  0.489578 -1.650002  82.953492  81.462000  79.970507
#
#             KD_1       KD_2        ADX      WILLR      BETA        TSF  \
# ...

# %%
pd.concat( [testdata.iloc[:, 2:5], testdata.iloc[:, 10], testdata.iloc[:, 13:15], testdata.iloc[:, -1]], axis=1)
# Out:
#              RSI      MACD       MOM        ADX        TSF      ROCP  \
# 0      43.920689 -0.624064  0.670000  27.608849  26.386484 -0.083639
# 1      36.866876 -0.324989 -0.440001  25.366484  26.626704 -0.018539
# 2      61.148764  0.504432  0.840000  29.331745  29.455054  0.019231
# 3      51.549343  0.194734 -0.139999  26.242291  29.399231 -0.012863
# 4      35.287002  0.314845 -1.560001  31.099914  31.339780 -0.018027
# ...          ...       ...       ...        ...        ...       ...
# 11358  35.912823  2.113382 -3.099998  33.722088  86.865166 -0.045662
# 11359  25.796770 -2.078858 -3.040001  28.531166  74.373517 -0.124599
# 11360  53.018605 -2.372954  0.650002  36.014725  69.700110 -0.038079
# 11361  65.575880  2.246607  5.570000  29.685040  85.329012  0.086814
# 11362  41.500225  0.489578 -1.650002  23.342904  80.142637 -0.036897
#
#               OBV
# 0      1750766779
# 1      1749798206
# 2      1751279112
# 3      1794765255
# 4      1830565324
# ...           ...
# ...

# %%
testdata_1 = pd.concat( [testdata.iloc[:, 2:5], testdata.iloc[:, 10], testdata.iloc[:, 13:15], testdata.iloc[:, -1]], axis=1)

# %%
result = clf.predict(testdata_1)

# %%
pd.DataFrame(result).to_excel("prediction.xlsx", index=False)

# %%
#整體績效0.50768

# %%
#RSI.MACD.MOM.ADX.TSF.ROCP.OBV 績效0.51833
